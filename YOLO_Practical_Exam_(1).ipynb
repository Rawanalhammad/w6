# %% [markdown]
# # Road Traffic Vehicle Counting Exam

# %% [markdown]
# In this exam, you will use the YOLO (You Only Look Once) object detection model to analyze a video of road traffic. Your primary task is to count the number of vehicles exiting the road at each of the four exits (located at the top, bottom, left, and right of the frame). The video for this task is provided at `Datasets/YOLO_Exam_Video.mp4`.
#
# ## Objectives
# - Load and process the video using OpenCV.
# - Utilize the YOLO model to detect vehicles in each frame.
# - Manipulate the video frames using OpenCV.
# - Track vehicles as they move across the video frames.
# - Count the number of vehicles exiting via the top street.
# - Count the number of vehicles exiting via the bottom street.
# - Count the number of vehicles exiting via the left street.
# - Count the number of vehicles exiting via the right street.

# %% [markdown]
# ## Setup Environment

# %% [markdown]
# Before you begin, ensure you have the necessary libraries installed. You will need `opencv`, and `ultralytics` among others.
# If these are not installed, you should install them.

# %%
# !pip install ultralytics
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.2.85-py3-none-any.whl.metadata (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.8/41.8 kB 1.2 MB/s eta 0:00:00
# Requirement already satisfied: numpy<2.0.0,>=1.23.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (1.26.4)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (3.7.1)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (4.10.0.84)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (9.4.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (1.13.1)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (2.4.0+cu121)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (0.19.0+cu121)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (4.66.5)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.10/dist-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (2.1.4)
# Requirement already satisfied: seaborn>=0.11.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (0.13.1)
# Collecting ultralytics-thop>=2.0.0 (from ultralytics)
#   Downloading ultralytics_thop-2.0.6-py3-none-any.whl.metadata (9.1 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.4->ultralytics) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.4->ultralytics) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (2024.7.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (3.15.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (1.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (2024.6.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.8.0->ultralytics) (1.3.0)
# Downloading ultralytics-8.2.85-py3-none-any.whl (872 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 872.3/872.3 kB 20.2 MB/s eta 0:00:00
# Downloading ultralytics_thop-2.0.6-py3-none-any.whl (26 kB)
# Installing collected packages: ultralytics-thop, ultralytics
# Successfully installed ultralytics-8.2.85 ultralytics-thop-2.0.6

# %%
import cv2
from ultralytics import YOLO
from IPython.display import Image, display
from IPython import display
import os
import numpy

# %% [markdown]
# ## Load the YOLO Model

# %% [markdown]
# You will first need to load the YOLO model, there is a custom model for this exam called `YOLO_Model.pt` under Datasets file ⚠️ PLEASE USE THIS MODEL AND DO NOT USE ANY OTHER MODEL ⚠️.
# Write the code to load the YOLO model below:

# %%
model = YOLO("/content/YOLO_Model.pt")

# %% [markdown]
# ## Prepare the Video Capture

# %% [markdown]
# Create a variable to capture the video frames, you can use `cv2.VideoCapture()` to achive this.

# %%
video = "/content/YOLO_Video.mp4"
cap = cv2.VideoCapture(video)

# %%
# !yolo task=detect mode=predict model=yolov8n.pt   conf=0.25 source='https://www.firsttimedriver.com/images/blog/traffic-rules-for-roundabouts.jpg'
# Out:
# Ultralytics YOLOv8.2.85 🚀 Python-3.10.12 torch-2.4.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n summary (fused): 168 layers, 3,151,904 parameters, 0 gradients, 8.7 GFLOPs
#
# Found https://www.firsttimedriver.com/images/blog/traffic-rules-for-roundabouts.jpg locally at traffic-rules-for-roundabouts.jpg
# image 1/1 /content/traffic-rules-for-roundabouts.jpg: 480x640 2 cars, 37.9ms
# Speed: 3.3ms preprocess, 37.9ms inference, 541.4ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs/detect/predict3
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
Image(filename='/content/runs/detect/predict2/traffic-rules-for-roundabouts.jpg', height=600)

# %% [markdown]
# ## Get Video Information

# %% [markdown]
# You can use `cv2` library to get these information fro the `VideoCapture()` variable you created to extract these information:
# * `height`: Video's height.
# * `width`: Video's width.
# * `fps`: Video's frames.

# %%
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps = int(cap.get(cv2.CAP_PROP_FPS))

# %%
print(width)
print(height)
print(fps)
# Out:
# 1920
# 1080
# 29

# %% [markdown]
# ## Prepare Video Writer to Store the Output

# %% [markdown]
# Create a variable that uses `cv2.VideoCapture()` to save the video with the bounding boxes, specified Region of Interest rectangle (ROI) and the counted vehicles on each sides. You will need to make the video with the same `fps`, `width`, `height`, and specify the codec and output path of the video.

# %%
output = '/content/output_video_with_yolov8.mp4'
fourcc = cv2.VideoWriter_fourcc(*'mp4v')
out = cv2.VideoWriter(output, fourcc, fps, (width, height))

# %%
color = (0, 255 ,0)
thickness = 2

# %%
ret , frame = cap.read()
results = model(frame)
# Out:
# 0: 384x640 2 buss, 90 cars, 2 trucks, 2 vans, 63.0ms
# Speed: 5.0ms preprocess, 63.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)

# %%
ret
# Out:
# True

# %%
frame
# Out:
# array([[[ 41,  77,  72],
#         [ 54,  90,  85],
#         [ 38,  79,  73],
#         ...,
#         [ 55,  51,  47],
#         [ 55,  51,  47],
#         [ 55,  51,  47]],
#
#        [[ 22,  58,  53],
#         [ 49,  85,  80],
#         [ 33,  74,  68],
#         ...,
#         [ 56,  52,  48],
#         [ 55,  51,  47],
#         [ 55,  51,  47]],
#
#        [[  6,  42,  37],
#         [ 40,  76,  71],
#         [ 34,  75,  69],
#         ...,
#         [ 55,  51,  47],
#         [ 55,  51,  47],
#         [ 54,  50,  46]],
#
#        ...,
#
#        [[128, 118, 194],
#         [111, 101, 177],
#         [ 99,  87, 163],
#         ...,
#         [108, 117, 123],
#         [108, 117, 123],
#         [108, 117, 123]],
#
#        [[117, 100, 183],
#         [101,  84, 167],
#         [112, 100, 164],
#         ...,
#         [110, 119, 125],
#         [108, 117, 123],
#         [108, 117, 123]],
#
#        [[ 99,  82, 165],
#         [106,  89, 172],
#         [126, 114, 178],
#         ...,
#         [110, 119, 125],
#         [110, 119, 125],
#         [110, 119, 125]]], dtype=uint8)

# %%
import matplotlib.pyplot as plt
plt.imshow(frame)

# %%
results[0].plot()
# Out:
# array([[[ 41,  77,  72],
#         [ 54,  90,  85],
#         [ 38,  79,  73],
#         ...,
#         [235, 219,  11],
#         [235, 219,  11],
#         [235, 219,  11]],
#
#        [[ 22,  58,  53],
#         [ 49,  85,  80],
#         [ 33,  74,  68],
#         ...,
#         [235, 219,  11],
#         [235, 219,  11],
#         [235, 219,  11]],
#
#        [[  6,  42,  37],
#         [ 40,  76,  71],
#         [ 34,  75,  69],
#         ...,
#         [235, 219,  11],
#         [235, 219,  11],
#         [235, 219,  11]],
#
#        ...,
#
#        [[128, 118, 194],
#         [111, 101, 177],
#         [ 99,  87, 163],
#         ...,
#         [108, 117, 123],
#         [108, 117, 123],
#         [108, 117, 123]],
#
#        [[117, 100, 183],
#         [101,  84, 167],
#         [112, 100, 164],
#         ...,
#         [110, 119, 125],
#         [108, 117, 123],
#         [108, 117, 123]],
#
#        [[ 99,  82, 165],
#         [106,  89, 172],
#         [126, 114, 178],
#         ...,
#         [110, 119, 125],
#         [110, 119, 125],
#         [110, 119, 125]]], dtype=uint8)

# %% [markdown]
# ## Expermint to get the `(x1, y1, x2, y2)` of the ROI

# %% [markdown]
# ### Hint
# When defining the Regions of Interest (ROIs) for detecting vehicles exiting the road, consider the coordinates that outline the relevant areas. These coordinates can be specified as `(x1, y1, x2, y2)`, where `(x1, y1)` is the top-left corner and `(x2, y2)` is the bottom-right corner of the rectangle.
#
# Experiment with different coordinates to accurately cover the streets where vehicles exit. Visualize these ROIs by drawing rectangles on a frame of the video and adjust the coordinates as needed until you capture the desired areas effectively.

# %%
for result in results:
    for box in result.boxes:
        print("Bounding Box:", box.xyxy)
        print("confidences:" , box.conf)
        print("class label index:" , box.cls)
# Out:
# Bounding Box: tensor([[1867.4952,   78.1810, 1900.9244,  141.1439]], device='cuda:0')
# confidences: tensor([0.8740], device='cuda:0')
# class label index: tensor([1.], device='cuda:0')
# Bounding Box: tensor([[1834.6637,  213.1610, 1880.2540,  286.1085]], device='cuda:0')
# confidences: tensor([0.8625], device='cuda:0')
# class label index: tensor([2.], device='cuda:0')
# Bounding Box: tensor([[1089.7432,  990.5244, 1128.7177, 1078.9347]], device='cuda:0')
# confidences: tensor([0.8608], device='cuda:0')
# class label index: tensor([0.], device='cuda:0')
# Bounding Box: tensor([[1648.5593,  652.6075, 1708.1426,  678.9460]], device='cuda:0')
# confidences: tensor([0.8481], device='cuda:0')
# class label index: tensor([1.], device='cuda:0')
# Bounding Box: tensor([[1079.2988,  540.2324, 1112.9175,  605.4812]], device='cuda:0')
# confidences: tensor([0.8470], device='cuda:0')
# class label index: tensor([1.], device='cuda:0')
# Bounding Box: tensor([[747.5092, 149.7538, 774.5188, 199.5782]], device='cuda:0')
# confidences: tensor([0.8461], device='cuda:0')
# class label index: tensor([1.], device='cuda:0')
# Bounding Box: tensor([[1036.7552,  641.5754, 1093.0784,  684.0400]], device='cuda:0')
# confidences: tensor([0.8457], device='cuda:0')
# class label index: tensor([1.], device='cuda:0')
# Bounding Box: tensor([[218.9239, 583.6733, 283.1158, 615.2202]], device='cuda:0')
# confidences: tensor([0.8454], device='cuda:0')
# class label index: tensor([1.], device='cuda:0')
# Bounding Box: tensor([[783.1379, 570.5427, 818.5512, 622.8283]], device='cuda:0')
# confidences: tensor([0.8428], device='cuda:0')
# class label index: tensor([1.], device='cuda:0')
# Bounding Box: tensor([[784.9076,  30.2460, 812.1116,  89.4373]], device='cuda:0')
# confidences: tensor([0.8421], device='cuda:0')
# class label index: tensor([1.], device='cuda:0')
# Bounding Box: tensor([[ 987.1038,  493.3323, 1030.9514,  541.9185]], device='cuda:0')
# confidences: tensor([0.8404], device='cuda:0')
# class label index: tensor([1.], device='cuda:0')
# Bounding Box: tensor([[751.9252,  62.4384, 776.8579, 122.8565]], device='cuda:0')
# confidences: tensor([0.8396], device='cuda:0')
# class label index: tensor([1.], device='cuda:0')
# Bounding Box: tensor([[ 15.6520, 519.1159,  75.5267, 547.5222]], device='cuda:0')
# confidences: tensor([0.8393], device='cuda:0')
# class label index: tensor([1.], device='cuda:0')
# Bounding Box: tensor([[ 54.0127, 384.4144, 115.8333, 414.0156]], device='cuda:0')
# confidences: tensor([0.8333], device='cuda:0')
# class label index: tensor([1.], device='cuda:0')
# Bounding Box: tensor([[691.0662, 391.8639, 746.0565, 421.8772]], device='cuda:0')
# confidences: tensor([0.8324], device='cuda:0')
# class label index: tensor([1.], device='cuda:0')
# Bounding Box: tensor([[750.3595, 549.3009, 785.1110, 599.7119]], device='cuda:0')
# confidences: tensor([0.8322], device='cuda:0')
# class label index: tensor([1.], device='cuda:0')
# Bounding Box: tensor([[1764.7910,   39.5971, 1826.8857,   69.4547]], device='cuda:0')
# confidences: tensor([0.8302], device='cuda:0')
# class label index: tensor([1.], device='cuda:0')
# Bounding Box: tensor([[282.5771, 560.3479, 345.5313, 592.4712]], device='cuda:0')
# confidences: tensor([0.8273], device='cuda:0')
# class label index: tensor([1.], device='cuda:0')
# Bounding Box: tensor([[736.0728, 436.6087, 793.8781, 465.8559]], device='cuda:0')
# confidences: tensor([0.8269], device='cuda:0')
# class label index: tensor([1.], device='cuda:0')
# Bounding Box: tensor([[1761.8624,  182.6611, 1796.3068,  239.7834]], device='cuda:0')
# confidences: tensor([0.8260], device='cuda:0')
# class label index: tensor([1.], device='cuda:0')
# Bounding Box: tensor([[193.3366, 402.4503, 252.9624, 430.7461]], device='cuda:0')
# confidences: tensor([0.8255], device='cuda:0')
# class label index: tensor([1.], device='cuda:0')
# Bounding Box: tensor([[  3.4678,  82.0800,  74.8115, 115.4242]], device='cuda:0')
# confidences: tensor([0.8249], device='cuda:0')
# class label index: tensor([1.], device='cuda:0')
# Bounding Box: tensor([[865.3280, 812.7220, 944.0432, 851.6646]], device='cuda:0')
# confidences: tensor([0.8239], device='cuda:0')
# class label index: tensor([3.], device='cuda:0')
# Bounding Box: tensor([[1142.0664,  976.1644, 1171.0479, 1036.3105]], device='cuda:0')
# confidences: tensor([0.8219], device='cuda:0')
# class label index: tensor([1.], device='cuda:0')
# Bounding Box: tensor([[  0.4613, 142.7270,  47.1279, 172.4381]], device='cuda:0')
# confidences: tensor([0.8215], device='cuda:0')
# class label index: tensor([1.], device='cuda:0')
# Bounding Box: tensor([[531.1391, 645.8143, 582.9345, 678.6458]], device='cuda:0')
# confidences: tensor([0.8215], device='cuda:0')
# class label index: tensor([1.], device='cuda:0')
# Bounding Box: tensor([[1148.0671,  482.3022, 1204.8181,  508.6216]], device='cuda:0')
# confidences: tensor([0.8185], device='cuda:0')
# class label index: tensor([1.], device='cuda:0')
# Bounding Box: tensor([[842.2756, 379.3799, 916.0851, 411.3794]], device='cuda:0')
# confidences: tensor([0.8173], device='cuda:0')
# class label index: tensor([1.], device='cuda:0')
# Bounding Box: tensor([[1870.8607,   13.9488, 1905.7423,   76.0679]], device='cuda:0')
# confidences: tensor([0.8171], device='cuda:0')
# class label index: tensor([1.], device='cuda:0')
# Bounding Box: tensor([[1.1182e+03, 1.0905e+00, 1.1475e+03, 5.5459e+01]], device='cuda:0')
# confidences: tensor([0.8132], device='cuda:0')
# class label index: tensor([1.], device='cuda:0')
# Bounding Box: tensor([[628.7663, 679.3600, 686.6987, 706.2457]], device='cuda:0')
# confidences: tensor([0.8121], device='cuda:0')
# class label index: tensor([1.], device='cuda:0')
# Bounding Box: tensor([[1841.5398, 1022.2104, 1879.9246, 1060.7915]], device='cuda:0')
# confidences: tensor([0.8120], device='cuda:0')
# class label index: tensor([1.], device='cuda:0')
# Bounding Box: tensor([[561.6752, 697.4658, 637.2918, 734.2451]], device='cuda:0')
# confidences: tensor([0.8108], device='cuda:0')
# class label index: tensor([1.], device='cuda:0')
# Bounding Box: tensor([[1561.0745,  452.0384, 1623.8405,  480.6008]], device='cuda:0')
# confidences: tensor([0.8100], device='cuda:0')
# class label index: tensor([1.], device='cuda:0')
# Bounding Box: tensor([[1719.6992,  653.0519, 1777.0332,  678.7612]], device='cuda:0')
# confidences: tensor([0.8088], device='cuda:0')
# class label index: tensor([1.], device='cuda:0')
# Bounding Box: tensor([[1017.9562,  379.1174, 1083.0754,  407.9748]], device='cuda:0')
# confidences: tensor([0.8084], device='cuda:0')
# class label index: tensor([1.], device='cuda:0')
# Bounding Box: tensor([[1176.0281,  394.8026, 1238.3658,  427.2440]], device='cuda:0')
# confidences: tensor([0.8083], device='cuda:0')
# class label index: tensor([1.], device='cuda:0')
# Bounding Box: tensor([[1178.1538, 1030.5321, 1205.4961, 1077.6743]], device='cuda:0')
# confidences: tensor([0.8081], device='cuda:0')
# class label index: tensor([1.], device='cuda:0')
# Bounding Box: tensor([[286.3148, 403.3127, 340.1738, 428.7237]], device='cuda:0')
# confidences: tensor([0.8050], device='cuda:0')
# class label index: tensor([1.], device='cuda:0')
# Bounding Box: tensor([[1568.7639,  652.3152, 1630.1274,  677.9941]], device='cuda:0')
# confidences: tensor([0.8037], device='cuda:0')
# class label index: tensor([1.], device='cuda:0')
# Bounding Box: tensor([[1430.4861,  487.6306, 1490.8193,  514.4581]], device='cuda:0')
# confidences: tensor([0.8024], device='cuda:0')
# class label index: tensor([1.], device='cuda:0')
# Bounding Box: tensor([[1323.3549,  443.8526, 1384.9922,  470.6525]], device='cuda:0')
# confidences: tensor([0.8000], device='cuda:0')
# class label index: tensor([1.], device='cuda:0')
# Bounding Box: tensor([[902.1136, 678.4459, 961.0709, 706.2274]], device='cuda:0')
# confidences: tensor([0.7994], device='cuda:0')
# class label index: tensor([1.], device='cuda:0')
# Bounding Box: tensor([[784.2753, 110.0086, 809.9232, 164.6518]], device='cuda:0')
# confidences: tensor([0.7990], device='cuda:0')
# class label index: tensor([1.], device='cuda:0')
# Bounding Box: tensor([[901.9510, 734.6074, 958.8756, 759.6284]], device='cuda:0')
# confidences: tensor([0.7985], device='cuda:0')
# class label index: tensor([1.], device='cuda:0')
# Bounding Box: tensor([[1248.7687,  482.7531, 1417.1125,  517.7898]], device='cuda:0')
# confidences: tensor([0.7981], device='cuda:0')
# class label index: tensor([0.], device='cuda:0')
# Bounding Box: tensor([[1037.5038,  712.5931, 1098.9683,  745.6257]], device='cuda:0')
# confidences: tensor([0.7937], device='cuda:0')
# class label index: tensor([1.], device='cuda:0')
# Bounding Box: tensor([[465.6351, 592.1534, 516.3958, 623.3688]], device='cuda:0')
# confidences: tensor([0.7936], device='cuda:0')
# class label index: tensor([1.], device='cuda:0')
# Bounding Box: tensor([[438.8777, 760.1589, 470.6359, 808.9861]], device='cuda:0')
# confidences: tensor([0.7885], device='cuda:0')
# class label index: tensor([1.], device='cuda:0')
# Bounding Box: tensor([[417.7272, 661.8462, 475.0759, 694.5054]], device='cuda:0')
# confidences: tensor([0.7831], device='cuda:0')
# class label index: tensor([1.], device='cuda:0')
# Bounding Box: tensor([[1757.9072,  453.5119, 1822.5129,  489.2660]], device='cuda:0')
# confidences: tensor([0.7823], device='cuda:0')
# class label index: tensor([1.], device='cuda:0')
# Bounding Box: tensor([[365.3051, 611.5043, 413.9793, 639.0319]], device='cuda:0')
# confidences: tensor([0.7804], device='cuda:0')
# class label index: tensor([1.], device='cuda:0')
# Bounding Box: tensor([[  0.0000, 640.2274,  41.6175, 693.6071]], device='cuda:0')
# confidences: tensor([0.7801], device='cuda:0')
# class label index: tensor([1.], device='cuda:0')
# Bounding Box: tensor([[1345.6412,  664.3934, 1395.9358,  691.7281]], device='cuda:0')
# confidences: tensor([0.7797], device='cuda:0')
# class label index: tensor([1.], device='cuda:0')
# Bounding Box: tensor([[1170.2820,  439.1960, 1226.2592,  465.6621]], device='cuda:0')
# confidences: tensor([0.7702], device='cuda:0')
# class label index: tensor([1.], device='cuda:0')
# Bounding Box: tensor([[919.8761, 473.7419, 974.1791, 499.5450]], device='cuda:0')
# confidences: tensor([0.7643], device='cuda:0')
# class label index: tensor([1.], device='cuda:0')
# Bounding Box: tensor([[639.5616, 629.1956, 700.4812, 660.0300]], device='cuda:0')
# confidences: tensor([0.7634], device='cuda:0')
# class label index: tensor([1.], device='cuda:0')
# Bounding Box: tensor([[1730.6678,  501.2147, 1784.3903,  526.1280]], device='cuda:0')
# confidences: tensor([0.7602], device='cuda:0')
# class label index: tensor([1.], device='cuda:0')
# Bounding Box: tensor([[1742.3837, 1020.7714, 1772.9883, 1059.1660]], device='cuda:0')
# confidences: tensor([0.7548], device='cuda:0')
# class label index: tensor([1.], device='cuda:0')
# Bounding Box: tensor([[800.9244, 497.3322, 862.6089, 549.4488]], device='cuda:0')
# confidences: tensor([0.7542], device='cuda:0')
# class label index: tensor([1.], device='cuda:0')
# Bounding Box: tensor([[1778.6938,  655.4021, 1843.8069,  680.9324]], device='cuda:0')
# confidences: tensor([0.7530], device='cuda:0')
# class label index: tensor([1.], device='cuda:0')
# Bounding Box: tensor([[1044.2511, 1005.9508, 1071.0186, 1051.9089]], device='cuda:0')
# confidences: tensor([0.7511], device='cuda:0')
# class label index: tensor([1.], device='cuda:0')
# Bounding Box: tensor([[1801.1821, 1021.6716, 1836.5244, 1052.4094]], device='cuda:0')
# confidences: tensor([0.7472], device='cuda:0')
# class label index: tensor([1.], device='cuda:0')
# Bounding Box: tensor([[1777.0037,  409.6609, 1831.3237,  434.8564]], device='cuda:0')
# confidences: tensor([0.7408], device='cuda:0')
# class label index: tensor([1.], device='cuda:0')
# Bounding Box: tensor([[1803.3157,  251.3790, 1837.1488,  325.4803]], device='cuda:0')
# confidences: tensor([0.7391], device='cuda:0')
# class label index: tensor([1.], device='cuda:0')
# Bounding Box: tensor([[1068.3206,  433.8624, 1122.5005,  458.0707]], device='cuda:0')
# confidences: tensor([0.7296], device='cuda:0')
# class label index: tensor([1.], device='cuda:0')
# Bounding Box: tensor([[1136.4170, 1044.3207, 1164.1084, 1079.5341]], device='cuda:0')
# confidences: tensor([0.7262], device='cuda:0')
# class label index: tensor([1.], device='cuda:0')
# Bounding Box: tensor([[1420.3732,  447.8193, 1489.1735,  476.1364]], device='cuda:0')
# confidences: tensor([0.7231], device='cuda:0')
# class label index: tensor([1.], device='cuda:0')
# Bounding Box: tensor([[1.8292e+03, 5.0286e-01, 1.8679e+03, 3.2050e+01]], device='cuda:0')
# confidences: tensor([0.7162], device='cuda:0')
# class label index: tensor([1.], device='cuda:0')
# Bounding Box: tensor([[718.0089, 701.5117, 788.8949, 733.4351]], device='cuda:0')
# confidences: tensor([0.7156], device='cuda:0')
# class label index: tensor([2.], device='cuda:0')
# Bounding Box: tensor([[1708.4290, 1021.7458, 1742.8169, 1058.8420]], device='cuda:0')
# confidences: tensor([0.7126], device='cuda:0')
# class label index: tensor([1.], device='cuda:0')
# Bounding Box: tensor([[1117.8264,  530.9636, 1147.8160,  586.5121]], device='cuda:0')
# confidences: tensor([0.7117], device='cuda:0')
# class label index: tensor([1.], device='cuda:0')
# Bounding Box: tensor([[104.0786, 525.4548, 154.0981, 551.8536]], device='cuda:0')
# confidences: tensor([0.7116], device='cuda:0')
# class label index: tensor([1.], device='cuda:0')
# Bounding Box: tensor([[9.7418e-03, 5.5435e+02, 2.9691e+01, 5.8006e+02]], device='cuda:0')
# confidences: tensor([0.7103], device='cuda:0')
# class label index: tensor([1.], device='cuda:0')
# Bounding Box: tensor([[1185.5833,  964.2888, 1212.2114, 1016.7754]], device='cuda:0')
# confidences: tensor([0.7096], device='cuda:0')
# class label index: tensor([1.], device='cuda:0')
# Bounding Box: tensor([[ 942.0970,  422.5882, 1009.7750,  453.3600]], device='cuda:0')
# confidences: tensor([0.7075], device='cuda:0')
# class label index: tensor([1.], device='cuda:0')
# Bounding Box: tensor([[843.3360, 456.3718, 909.7381, 484.1600]], device='cuda:0')
# confidences: tensor([0.7070], device='cuda:0')
# class label index: tensor([1.], device='cuda:0')
# Bounding Box: tensor([[1884.1069, 1024.0544, 1918.9556, 1055.8345]], device='cuda:0')
# confidences: tensor([0.7011], device='cuda:0')
# class label index: tensor([1.], device='cuda:0')
# Bounding Box: tensor([[218.2348, 471.8274, 285.5207, 499.1968]], device='cuda:0')
# confidences: tensor([0.6972], device='cuda:0')
# class label index: tensor([1.], device='cuda:0')
# Bounding Box: tensor([[1117.4056,  167.7453, 1143.2198,  218.6032]], device='cuda:0')
# confidences: tensor([0.6958], device='cuda:0')
# class label index: tensor([1.], device='cuda:0')
# Bounding Box: tensor([[  0.0000, 373.3275,  27.9603, 403.4511]], device='cuda:0')
# confidences: tensor([0.6900], device='cuda:0')
# class label index: tensor([1.], device='cuda:0')
# Bounding Box: tensor([[1768.1990,  113.5319, 1818.8562,  137.3292]], device='cuda:0')
# confidences: tensor([0.6727], device='cuda:0')
# class label index: tensor([1.], device='cuda:0')
# Bounding Box: tensor([[1676.1201, 1022.4738, 1709.5420, 1057.1538]], device='cuda:0')
# confidences: tensor([0.6705], device='cuda:0')
# class label index: tensor([1.], device='cuda:0')
# Bounding Box: tensor([[1448.0586,  408.4362, 1499.6172,  434.8531]], device='cuda:0')
# confidences: tensor([0.6562], device='cuda:0')
# class label index: tensor([1.], device='cuda:0')
# Bounding Box: tensor([[1067.1870,  484.8616, 1116.8280,  507.5152]], device='cuda:0')
# confidences: tensor([0.6441], device='cuda:0')
# class label index: tensor([1.], device='cuda:0')
# Bounding Box: tensor([[709.0315, 542.5743, 749.3140, 599.3564]], device='cuda:0')
# confidences: tensor([0.6079], device='cuda:0')
# class label index: tensor([3.], device='cuda:0')
# Bounding Box: tensor([[1775.5786, 1021.7847, 1804.2607, 1051.8152]], device='cuda:0')
# confidences: tensor([0.6070], device='cuda:0')
# class label index: tensor([1.], device='cuda:0')
# Bounding Box: tensor([[1894.1005,  445.4695, 1919.8597,  486.8568]], device='cuda:0')
# confidences: tensor([0.6045], device='cuda:0')
# class label index: tensor([1.], device='cuda:0')
# Bounding Box: tensor([[1613.8198,  408.6773, 1680.8438,  433.4203]], device='cuda:0')
# confidences: tensor([0.5834], device='cuda:0')
# class label index: tensor([1.], device='cuda:0')
# Bounding Box: tensor([[789.8476,   0.0000, 817.3726,  16.0530]], device='cuda:0')
# confidences: tensor([0.5352], device='cuda:0')
# class label index: tensor([1.], device='cuda:0')
# Bounding Box: tensor([[1669.7681,  454.4004, 1729.6406,  481.1979]], device='cuda:0')
# confidences: tensor([0.5329], device='cuda:0')
# class label index: tensor([1.], device='cuda:0')
# Bounding Box: tensor([[ 77.8351, 569.1405, 152.2896, 597.7233]], device='cuda:0')
# confidences: tensor([0.3876], device='cuda:0')
# class label index: tensor([1.], device='cuda:0')
# Bounding Box: tensor([[1764.1992,  136.7270, 1814.5525,  169.5379]], device='cuda:0')
# confidences: tensor([0.3449], device='cuda:0')
# class label index: tensor([1.], device='cuda:0')
# Bounding Box: tensor([[1723.0605, 1021.6265, 1749.1531, 1059.3020]], device='cuda:0')
# confidences: tensor([0.3081], device='cuda:0')
# class label index: tensor([1.], device='cuda:0')
# Bounding Box: tensor([[1875.6106,   12.8675, 1915.6580,   76.3438]], device='cuda:0')
# confidences: tensor([0.2806], device='cuda:0')
# class label index: tensor([1.], device='cuda:0')
# Bounding Box: tensor([[359.8933, 606.4328, 417.2734, 639.9647]], device='cuda:0')
# confidences: tensor([0.2548], device='cuda:0')
# class label index: tensor([1.], device='cuda:0')

# %% [markdown]
# ## Process Video Frames and Identify Vehicles Left the Road Form Each Street

# %% [markdown]
# For each frame in the video, use the YOLO model to detect and track vehicles. You will need to write a loop that processes each frame and applies the YOLO model.
#
# In each frame, after detecting the vehicles, determine whether they exited the road via the top, bottom, left, or right street. You can use the positions of the bounding boxes provided by YOLO to do this.
#
# - The video should display bounding boxes around the detected objects.
# - The video should display your name on the top.
# - It should display the calculated center of each vehicle.
# - The video should display the confidence score, alongside the object ID and class ID of each detected and tracked object.
# - The video should display the rectangles representing the regions where you count the vehicles that have crossed and exited.
# - The video should display the number of vehicles that exited via the top street.
# - The video should display the number of vehicles that exited via the bottom street.
# - The video should display the number of vehicles that exited via the left street.
# - The video should display the number of vehicles that exited via the right street.

# %%
color = (0, 255 ,0)
thickness = 2

while cap.isOpened():
  ret, frame = cap.read()
  if not ret :
      break
  results = model(frame)
  vehicle_count=0
  for result in results:
      boxes = result.boxes.xyxy.cpu().numpy()
      confidences = result.boxes.conf.cpu().numpy()
      class_ids = result.boxes.cls.cpu().numpy()

      for box, conf, class_id in zip(boxes, confidences, class_ids):
               x1,y1,x2,y2 =map(int, box)
               label = f'{model.names[int(class_id)]}: {conf:.2f}'
               if model.names[int(class_id)] in ['car', truck, 'bus']:
                   vehicle_count+=1
               cv2.rectangle(frame , (x1,y1), (x2, y2), color , thickness)
               cv2.putText(frame, label, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, color, thickness)
      cv.putText(frame,f'Vehicles: {vehicle_count}', (10,30), cv2.FONT_HERSHEY_SIMPLEX, 1 ,color, thickness)
out.write(frame)
cap.release()
out.release()

print(f"Video saved to {output}")
# Out:
# Video saved to /content/output_video_with_yolov8.mp4

# %% [markdown]
# ## Save and Submit Your Work

# %% [markdown]
# Submit both the notebook and the output video
